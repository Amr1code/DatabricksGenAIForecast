-- %%
SELECT CAST(Promo AS STRING) as Promo, AVG(Sales) as AvgSales, COUNT(*) as DayCount
FROM retail_project.gold.sales_features
GROUP BY Promo
-- Out:
-- Databricks visualization. Run in Databricks to view.
