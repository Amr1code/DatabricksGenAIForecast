-- %%
SELECT CAST(Store AS STRING) as Store, AVG(Sales) as AvgSales
FROM retail_project.gold.sales_features
GROUP BY Store
ORDER BY AvgSales DESC
LIMIT 10
-- Out:
-- Databricks visualization. Run in Databricks to view.
